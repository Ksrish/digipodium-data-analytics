# %%
x = 100

# %%
if x > 1000:
    print("x is greater than 10")

# %%
name = "William Shakespeare"

# %%
'will' in name
# Out:
# False

# %%
'Will' in name
# Out:
# True

# %%
if 'spear' in name:
    print ('spear found in name')
# Out:
# spear found in name

# %%
if 'Shakes' in name:
    print('Shakes found in name')
# Out:
# Shakes found in name

# %%
age = int(input('what is your age:'))
if age >= 18:
    print('you are an adult')
    print('you can vote')
else:
    print('you are child')
    print('you cannot vote')
    print('you can vote in',18 - age,'years')
# Out:
# you are an adult
# you can vote

# %%
age = int(input('what is your age:'))
if age >= 18:
    print('you are an adult')
    print('you can vote')
else:
    print('you are child')
    print('you cannot vote')
    print('you can vote in',18 - age,'years')
# Out:
# you are child
# you cannot vote
# you can vote in 1 years

# %%
# if elif else ladder
print('welcome to the 🍦 🏪 🍦')
flavour = input ('what flavour do you want?')
if flavour == 'vanilla':
    print('here is your vanilla 🍦')
elif flavour =='chocolate':
    print('here is your chocolate 🍦')
elif flavour == 'butterscotch':
    print('here is your butterscotch 🍦')
else:
    print('sorry we do not have', flavour,'flavour')
# Out:
# welcome to the 🍦 🏪 🍦
# sorry we do not have strawberry flavour

# %%
# if elif else ladder
print('welcome to the 🍦 🏪 🍦')
flavour = input ('what flavour do you want?')
if flavour == 'vanilla':
    print('here is your vanilla 🍦')
elif flavour =='chocolate':
    print('here is your chocolate 🍦')
elif flavour == 'butterscotch':
    print('here is your butterscotch 🍦')
else:
    print('sorry we do not have', flavour,'flavour')
# Out:
# welcome to the 🍦 🏪 🍦
# here is your chocolate 🍦
